# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
training=pd.read_csv("dirty_data.csv")

# %%
dataset.index=dataset.Id
dataset=dataset.drop(columns="Id")
dataset
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# there are 199 missing value in lotFrontage ,expected :(deleting the rows ),fill with mean value done .
# there are 1309 missing value in Alley (deleting the column ) done.
# there are 872 missing value in MasVnrType (deleting the column ) done.
# there are 8 missing value in MasVnrArea ,expected :(deleting the column ),fill with value "0.0" done.
# there are 37 missing value in BsmtCond ,expected : (deleting the column ),fill with most repeated value "TA" done.
# there are 37 missing value in BsmtQual (deleting the column ),filling without changing the distribution of values done.
# there are 38 missing value in BsmtExposure(deleting the column ),filling without changing the distribution of values done.
# there are 37 missing value in BsmtFinType1(deleting the column ),filling without changing the distribution of values done.
# there are 38 missing value in BsmtFinType2 (deleting the column ),fill with most repeated value "Unf" done.
# there are 1 missing value in Electrical (deleting the column ),fill it with most repeated value "SBrkr" done.
# there are 630 missing value in FireplaceQu (deleting the column ) done.
# there are 81 missing value in GarageType (deleting the column ) fill without changing the distribution of values done.
# there are 81 missing value in GarageYrBlt (deleting the column) fiil without changing the distribution of values done.
# there are 81 missing value in GarageFinish (deleting the column )fill without changing the distribution of values done.
# there are 81 missing value in GarageQual (deleting the column )fill with most repeated value "TA" done.
# there are 81 missing value in GarageCond (deleting the column )fill with most repeated value "TA" done.
# there are 1453 missing value in PoolQC (deleting the column ) done.
# there are 1179 missing value in Fence (deleting the column ) done.
# there are 1406 missing value in MiscFeature (deleting the column )done.
#
# DOONE.
#
# ONE-HOTon carrying out

# %%
dataset["Alley"].value_counts()
#dataset["RoofStyle"].count()
# Out:
# Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64

# %%
dataset["Alley"].count()
# Out:
# np.int64(198)

# %%
mask=dataset.loc[dataset.LotFrontage.notna()].index
#unwanted_location=cafe_sales.loc[cafe_sales.Item.isin(unwanted)].index
meanfrontage=np.mean(dataset.loc[mask,'LotFrontage'])
#print(mask)
mask=dataset.loc[dataset.LotFrontage.isna()].index
dataset.loc[mask,"LotFrontage"]=meanfrontage
dataset["LotFrontage"].count()
#dataset["RoofStyle"].count()
# Out:
# np.int64(2919)

# %%
dataset=dataset.drop(columns="Alley")

# %%
dataset=dataset.drop(columns="MasVnrType")

# %%
mask=dataset.loc[dataset.MasVnrArea.isna()].index
dataset.loc[mask,"MasVnrArea"]=0.0
#done

# %%
mask=dataset.loc[dataset.BsmtCond.isna()].index
dataset.loc[mask,"BsmtCond"]="TA"
#done

# %%
proportions=dataset["BsmtQual"].value_counts(normalize=True)
size=dataset["BsmtQual"].isnull().sum()
missing_mask=dataset["BsmtQual"].isnull()
fill_value=np.random.choice(proportions.index,size=size,p=proportions.values)
dataset.loc[missing_mask,"BsmtQual"]=fill_value

# %%
proportions=dataset["BsmtExposure"].value_counts(normalize=True)
size=dataset["BsmtExposure"].isnull().sum()
missing_mask=dataset["BsmtExposure"].isnull()
fill_value=np.random.choice(proportions.index,size=size,p=proportions.values)
dataset.loc[missing_mask,"BsmtExposure"]=fill_value
dataset.BsmtExposure.value_counts()
# Out:
# BsmtExposure
# No    1963
# Av     431
# Gd     284
# Mn     241
# Name: count, dtype: int64

# %%
proportions=dataset["BsmtFinType1"].value_counts(normalize=True)
size=dataset["BsmtFinType1"].isnull().sum()
missing_mask=dataset["BsmtFinType1"].isnull()
fill_value=np.random.choice(proportions.index,size=size,p=proportions.values)
dataset.loc[missing_mask,"BsmtFinType1"]=fill_value
dataset.BsmtFinType1.value_counts()
# Out:
# BsmtFinType1
# GLQ    876
# Unf    872
# ALQ    445
# Rec    294
# BLQ    274
# LwQ    158
# Name: count, dtype: int64

# %%
mask=dataset.loc[dataset.BsmtFinType2.isna()].index
dataset.loc[mask,"BsmtFinType2"]="Unf"
dataset.BsmtFinType2.value_counts()
# Out:
# BsmtFinType2
# Unf    2573
# Rec     105
# LwQ      87
# BLQ      68
# ALQ      52
# GLQ      34
# Name: count, dtype: int64

# %%
mask=dataset.loc[dataset.Electrical.isna()].index
dataset.loc[mask,"Electrical"]="SBrkr"

dataset.Electrical.value_counts()
# Out:
# Electrical
# SBrkr    2672
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: count, dtype: int64

# %%
dataset=dataset.drop(columns="FireplaceQu")

# %%
proportions=dataset["GarageType"].value_counts(normalize=True)
size=dataset["GarageType"].isnull().sum()
missing_mask=dataset["GarageType"].isnull()
fill_value=np.random.choice(proportions.index,size=size,p=proportions.values)
dataset.loc[missing_mask,"GarageType"]=fill_value
dataset.GarageType.value_counts()
# Out:
# GarageType
# Attchd     1826
# Detchd      822
# BuiltIn     194
# Basment      37
# 2Types       23
# CarPort      17
# Name: count, dtype: int64

# %%
proportions=dataset["GarageYrBlt"].value_counts(normalize=True)
size=dataset["GarageYrBlt"].isnull().sum()
missing_mask=dataset["GarageYrBlt"].isnull()
fill_value=np.random.choice(proportions.index,size=size,p=proportions.values)
dataset.loc[missing_mask,"GarageYrBlt"]=fill_value
dataset.GarageYrBlt.value_counts()
# Out:
# GarageYrBlt
# 2005.0    151
# 2007.0    125
# 2006.0    123
# 2004.0    104
# 2003.0     95
#          ...
# 1933.0      1
# 1896.0      1
# 1895.0      1
# 2207.0      1
# 1943.0      1
# Name: count, Length: 103, dtype: int64

# %%
proportions=dataset["GarageFinish"].value_counts(normalize=True)
size=dataset["GarageFinish"].isnull().sum()
missing_mask=dataset["GarageFinish"].isnull()
fill_value=np.random.choice(proportions.index,size=size,p=proportions.values)
dataset.loc[missing_mask,"GarageFinish"]=fill_value
dataset.GarageFinish.value_counts()
# Out:
# GarageFinish
# Unf    1321
# RFn     847
# Fin     751
# Name: count, dtype: int64

# %%
mask=dataset.loc[dataset.GarageQual.isna()].index
dataset.loc[mask,"GarageQual"]="TA"
dataset["GarageQual"].value_counts()
# Out:
# GarageQual
# TA    2763
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: count, dtype: int64

# %%
mask=dataset.loc[dataset.GarageCond.isna()].index
dataset.loc[mask,"GarageCond"]="TA"
dataset.GarageCond.values.value_counts()
# Out:
# TA    2813
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: count, dtype: int64

# %%
dataset=dataset.drop(columns="PoolQC")

# %%
dataset=dataset.drop(columns="Fence")

# %%
dataset=dataset.drop(columns="MiscFeature")

# %%
dataset.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
dateColumns=['YearBuilt','YearRemodAdd','GarageYrBlt','YrSold']
#transfer data type to datetime
for i in dateColumns:
    
    dataset[i]=pd.to_datetime(dataset[i])
        
    print(dataset[i])
# Out:
# Id
# 1      1970-01-01 00:00:00.000002003
# 2      1970-01-01 00:00:00.000001976
# 3      1970-01-01 00:00:00.000002001
# 4      1970-01-01 00:00:00.000001915
# 5      1970-01-01 00:00:00.000002000
#                     ...
# 2915   1970-01-01 00:00:00.000001970
# 2916   1970-01-01 00:00:00.000001970
# 2917   1970-01-01 00:00:00.000001960
# 2918   1970-01-01 00:00:00.000001992
# 2919   1970-01-01 00:00:00.000001993
# Name: YearBuilt, Length: 2919, dtype: datetime64[ns]
# Id
# 1      1970-01-01 00:00:00.000002003
# 2      1970-01-01 00:00:00.000001976
# 3      1970-01-01 00:00:00.000002002
# 4      1970-01-01 00:00:00.000001970
# 5      1970-01-01 00:00:00.000002000
#                     ...
# 2915   1970-01-01 00:00:00.000001970
# 2916   1970-01-01 00:00:00.000001970
# 2917   1970-01-01 00:00:00.000001996
# 2918   1970-01-01 00:00:00.000001992
# 2919   1970-01-01 00:00:00.000001994
# Name: YearRemodAdd, Length: 2919, dtype: datetime64[ns]
# Id
# 1      1970-01-01 00:00:00.000002003
# ...

# %%
stringColumns=[]
for i in dataset:
    if (dataset[i].dtype=="str"):
       stringColumns.append(i)        
dataset=pd.get_dummies(dataset,columns=stringColumns,drop_first=True)
print(f"missing values left : {dataset.isnull().sum().sum()}")     
print(f"Non-numeric columns : {dataset.select_dtypes(include='object').columns}")
# Out:
# missing values left : 1469
# Non-numeric columns : Index([], dtype='str')

# %%
# 1. تحديد كل الأعمدة اللي نوعها مو رقمي (object أو category)
cols_to_encode = dataset.select_dtypes(exclude=['number']).columns.tolist()

# 2. تحويلهم لـ One-Hot Encoding بضربة وحدة
dataset = pd.get_dummies(dataset, columns=cols_to_encode, drop_first=True)

# 3. فحص أخير: هل لسا في أعمدة نصوص؟
remaining_objects = dataset.select_dtypes(include=['object']).columns.tolist()
print(f"Remaining non-numeric columns: {remaining_objects}")
# Out:
# Remaining non-numeric columns: []

# %%
import re
dataset.columns = [re.sub(r'[\[\]<>]', '', col) for col in dataset.columns]
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2919 entries, 1 to 2919
# Columns: 509 entries, MSSubClass to SaleCondition_Partial_True
# dtypes: bool(476), float64(11), int64(22)
# memory usage: 2.1 MB

# %%
train_final = dataset.iloc[:1460, :].copy()
test_final = dataset.iloc[1460:, :].copy()

test_final = test_final.drop('SalePrice', axis=1)
train_final.to_csv("cleaned_data_training.csv", index=False)

# %%
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        ...
#        'SaleType_ConLI_True', 'SaleType_ConLw_True', 'SaleType_New_True',
#        'SaleType_Oth_True', 'SaleType_WD_True', 'SaleCondition_AdjLand_True',
#        'SaleCondition_Alloca_True', 'SaleCondition_Family_True',
#        'SaleCondition_Normal_True', 'SaleCondition_Partial_True'],
#       dtype='str', length=508)
